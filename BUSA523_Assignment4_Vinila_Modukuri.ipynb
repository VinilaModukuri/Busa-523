# %% [markdown]
# # 1. Using the dataset provided, develop the following visualizations using the right set of variables. (20 each) a. Histogram b. Bar chart c. Line chart d. Area chart e. Scatter plot

# %%
import matplotlib.pyplot as plt
import pandas as pd
plt.style.use('seaborn-pastel')


dv = pd.read_csv("data.csv", header = 0, index_col = 0)

dv
# Out:
#             Temperature  Fuel_Price  MarkDown1  MarkDown2  MarkDown3  \
# Date
# 5/2/10            42.31       2.572        NaN        NaN        NaN
# 12/2/10           38.51       2.548        NaN        NaN        NaN
# 19/02/2010        39.93       2.514        NaN        NaN        NaN
# 26/02/2010        46.63       2.561        NaN        NaN        NaN
# 5/3/10            46.50       2.625        NaN        NaN        NaN
# ...                 ...         ...        ...        ...        ...
# 28/09/2012        76.08       3.666    3666.27       7.64       1.65
# 5/10/12           68.55       3.617    8077.89        NaN      18.22
# 12/10/12          62.99       3.601    2086.18        NaN       8.11
# 19/10/2012        67.97       3.594     950.33        NaN       4.93
# 26/10/2012        69.16       3.506    2585.85      31.75       6.00
#
#             MarkDown4  MarkDown5         CPI  Unemployment     Day type  \
# Date
# ...

# %%
dv.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
dv.plot.bar()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
dv.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
dv.plot.area()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
dv.plot.scatter('dept_1 sales','dept_2 sales')
# Out:
# <AxesSubplot:xlabel='dept_1 sales', ylabel='dept_2 sales'>
